# %%
## Seaborn for plotting

import seaborn as sns
import pandas as pd
import numpy as np


data = np.random.randn(100, 2)
data
# Out:
# array([[-0.51459561,  0.42750634],
#        [-1.06531472,  1.04884743],
#        [ 1.66905262, -0.23992037],
#        [ 0.83394958,  0.78793811],
#        [-0.14312769, -1.75684999],
#        [-0.15889727, -2.59862202],
#        [ 1.61148569,  0.28191046],
#        [-2.20147567,  1.07273061],
#        [ 0.3739167 ,  1.38378942],
#        [-0.45111108, -0.73154588],
#        [-0.83273788,  0.82466351],
#        [-0.78013975, -0.38251958],
#        [-1.88291301,  1.19220391],
#        [-1.06248094,  0.03513061],
#        [ 0.81443858, -0.56358507],
#        [ 0.06715538, -1.22473745],
#        [-0.30759085, -1.14820263],
#        [-1.18914784, -0.68242467],
#        [ 1.47827425, -2.34168033],
#        [-0.77622944,  0.67657911],
#        [ 0.78075699, -1.17293954],
#        [ 0.45859627, -0.93379645],
#        [-1.75163737,  0.28430828],
#        [ 0.52960967,  1.87740276],
#        [-0.84524565, -0.20594825],
#        [-0.16478263,  1.01159031],
#        [ 1.56114459,  0.42922307],
# ...

# %%
sns.pairplot(data = pd.DataFrame(data), kind = 'reg', height = 2.5)

# %%
data = pd.read_csv("/Users/balmukundmishra/Desktop/2025-Learning/ML-Course/Datasets/Customer_Churn_Modelling.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
sns.lineplot(data=data, x = 'Age', y = "Balance", hue= 'Exited', style = 'Exited', markers = True, dashes = False)
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
sns.lineplot(data=data, x = 'Age', y = "Balance")
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
sns.barplot(data=data, x='Age', y='Balance', hue='Exited')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
sns.barplot(data=data, x='Age', y='Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
## Categorical plot
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
sns.barplot(data=data, x= 'Geography', y='Balance', hue='Exited')
# Out:
# <Axes: xlabel='Geography', ylabel='Balance'>

# %%
sns.boxplot(data=data, x='Geography', y='Balance', hue='Exited')
# Out:
# <Axes: xlabel='Geography', ylabel='Balance'>
