# %%
paragraph = """
On July 17, 2014, Malaysia Airlines Flight MH17, en route from Amsterdam to Kuala Lumpur, was shot down over eastern Ukraine, killing all 298 passengers, including 80 children and several leading AIDS researchers heading to the 20th International AIDS Conference in Melbourne. 
Among the victims was Joep Lange, a Dutch HIV researcher and former president of the International AIDS Society. 
The incident led to severe diplomatic fallout between Russia and Western nations, with U.S. President Barack Obama and German Chancellor Angela Merkel jointly urging for sanctions against the Kremlin. 
Meanwhile, Boeing, the manufacturer of the ill-fated 777 aircraft, saw its stock dip slightly on the New York Stock Exchange before recovering later that week. Investigations were led by the Dutch Safety Board in coordination with Eurocontrol and NATO surveillance data, amid accusations involving the Russian-backed Donetsk People's Republic.
"""

# %%
import nltk
words = nltk.word_tokenize(paragraph)

# %%
tag_element = nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/balmukundmishra/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/balmukundmishra/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
nltk.ne_chunk(tag_element).draw()

# %%
nltk.ne_chunk(tag_element)
# Out:
# Tree('S', [('On', 'IN'), ('July', 'NNP'), ('17', 'CD'), (',', ','), ('2014', 'CD'), (',', ','), Tree('GPE', [('Malaysia', 'NNP')]), Tree('PERSON', [('Airlines', 'NNPS'), ('Flight', 'NNP'), ('MH17', 'NNP')]), (',', ','), ('en', 'FW'), ('route', 'NN'), ('from', 'IN'), Tree('GPE', [('Amsterdam', 'NNP')]), ('to', 'TO'), Tree('PERSON', [('Kuala', 'NNP'), ('Lumpur', 'NNP')]), (',', ','), ('was', 'VBD'), ('shot', 'VBN'), ('down', 'RB'), ('over', 'IN'), ('eastern', 'JJ'), Tree('GPE', [('Ukraine', 'NNP')]), (',', ','), ('killing', 'VBG'), ('all', 'DT'), ('298', 'CD'), ('passengers', 'NNS'), (',', ','), ('including', 'VBG'), ('80', 'CD'), ('children', 'NNS'), ('and', 'CC'), ('several', 'JJ'), ('leading', 'VBG'), Tree('ORGANIZATION', [('AIDS', 'NNP')]), ('researchers', 'NNS'), ('heading', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('20th', 'JJ'), Tree('ORGANIZATION', [('International', 'NNP')]), ('AIDS', 'NNP'), ('Conference', 'NNP'), ('in', 'IN'), Tree('GPE', [('Melbourne', 'NNP')]), ('.', '.'), ('A
# ...

# %%
# !pip install svgling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 1.2 MB/s eta 0:00:00a 0:00:01
# ...
